# %% [markdown]
# <a href="https://colab.research.google.com/github/LauraAlejandraFuentesArevalo/DS_Laura_Alejandra_Fuentes/blob/main/clase7_Oct3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print('** Versiones Actuales | Requeridas **')
print('NumPy: Version Actual:', np.__version__)
print('Pandas: Version Actual:', pd.__version__)
# Out:
# ** Versiones Actuales | Requeridas **
# NumPy: Version Actual: 1.21.6
# Pandas: Version Actual: 1.3.5

# %%
ruta = "/content/drive/MyDrive/Colab Notebooks/data_set/claseOct3.csv"

# %%
df = pd.read_csv(filepath_or_buffer=ruta)

# %%
df
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 170830  snscrape.modules.twitter.Tweet
# 170831  snscrape.modules.twitter.Tweet
# 170832  snscrape.modules.twitter.Tweet
# 170833  snscrape.modules.twitter.Tweet
# 170834  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/pat_ianni/status/150025982...
# 1       https://twitter.com/luxeprogressive/status/150...
# 2       https://twitter.com/spielblog/status/150025947...
# 3       https://twitter.com/JumboSlunce/status/1500259...
# 4       https://twitter.com/ronanmcmanus/status/150025...
# ...                                                   ...
# 170830  https://twitter.com/Hansthewise/status/1476708...
# ...

# %%
df_prueba=df

# %%
df_prueba.keys()
# Out:
# Index(['_type', 'url', 'date', 'content', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel',
#        'outlinks', 'tcooutlinks', 'media', 'retweetedTweet', 'quotedTweet',
#        'inReplyToTweetId', 'inReplyToUser', 'mentionedUsers', 'coordinates',
#        'place', 'hashtags', 'cashtags', 'Searh'],
#       dtype='object')

# %%
#Cambiaré los vacios por 0
df_prueba1=df_prueba.fillna(0)
df_prueba1
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 170830  snscrape.modules.twitter.Tweet
# 170831  snscrape.modules.twitter.Tweet
# 170832  snscrape.modules.twitter.Tweet
# 170833  snscrape.modules.twitter.Tweet
# 170834  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/pat_ianni/status/150025982...
# 1       https://twitter.com/luxeprogressive/status/150...
# 2       https://twitter.com/spielblog/status/150025947...
# 3       https://twitter.com/JumboSlunce/status/1500259...
# 4       https://twitter.com/ronanmcmanus/status/150025...
# ...                                                   ...
# 170830  https://twitter.com/Hansthewise/status/1476708...
# ...

# %%
df_prueba1.keys()
# Out:
# Index(['_type', 'url', 'date', 'content', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel',
#        'outlinks', 'tcooutlinks', 'media', 'retweetedTweet', 'quotedTweet',
#        'inReplyToTweetId', 'inReplyToUser', 'mentionedUsers', 'coordinates',
#        'place', 'hashtags', 'cashtags', 'Searh'],
#       dtype='object')

# %%
df_prueba2=df_prueba1["date"]
df_prueba2
# Out:
# 0         2022-03-05 23:59:50+00:00
# 1         2022-03-05 23:59:05+00:00
# 2         2022-03-05 23:58:26+00:00
# 3         2022-03-05 23:58:20+00:00
# 4         2022-03-05 23:58:17+00:00
#                     ...
# 170830    2021-12-31 00:15:17+00:00
# 170831    2021-12-31 00:08:30+00:00
# 170832    2021-12-31 00:05:51+00:00
# 170833    2021-12-31 00:05:33+00:00
# 170834    2021-12-31 00:02:49+00:00
# Name: date, Length: 170835, dtype: object

# %%
df_prueba2.describe()
# Out:
# count                        170835
# unique                       163427
# top       2022-02-11 23:58:33+00:00
# freq                             10
# Name: date, dtype: object

# %%
#cambiar el formato a los datos de año
#2021-12-31 00:15:17+00:00
df_prueba2= pd.to_datetime(df_prueba2, format = '%Y-%m-%d %H:%M:%S')

# %%
df_prueba3=df_prueba1[['replyCount', 'retweetCount', 'likeCount']]
df_prueba3
# Out:
#         replyCount  retweetCount  likeCount
# 0               14            26         99
# 1                0             0          2
# 2                1             0          0
# 3                1             0          0
# 4                0             0          0
# ...            ...           ...        ...
# 170830           0             0          0
# 170831           0             0          0
# 170832           1             0          0
# 170833           0             0          1
# 170834           0             0          0
#
# [170835 rows x 3 columns]

# %%
df_prueba3.dtypes
# Out:
# replyCount      int64
# retweetCount    int64
# likeCount       int64
# dtype: object

# %%
df_prueba3['replyCount']=df_prueba3['replyCount'].astype(float)

df_prueba3['retweetCount']=df_prueba3['retweetCount'].astype(float)

df_prueba3['likeCount']=df_prueba3['likeCount'].astype(float)

df_prueba3.dtypes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
#Copiar todas las que se modificaron separadas en la prueba 1
df_prueba1['date']=df_prueba2
df_prueba1['replyCount']=df_prueba3['replyCount']
df_prueba1['retweetCount']=df_prueba3['retweetCount']
df_prueba1['likeCount']=df_prueba3['likeCount']

# %%
df_prueba1
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 170830  snscrape.modules.twitter.Tweet
# 170831  snscrape.modules.twitter.Tweet
# 170832  snscrape.modules.twitter.Tweet
# 170833  snscrape.modules.twitter.Tweet
# 170834  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/pat_ianni/status/150025982...
# 1       https://twitter.com/luxeprogressive/status/150...
# 2       https://twitter.com/spielblog/status/150025947...
# 3       https://twitter.com/JumboSlunce/status/1500259...
# 4       https://twitter.com/ronanmcmanus/status/150025...
# ...                                                   ...
# 170830  https://twitter.com/Hansthewise/status/1476708...
# ...

# %%
df_prueba1.dtypes
# Out:
# _type                            object
# url                              object
# date                datetime64[ns, UTC]
# content                          object
# renderedContent                  object
# id                                int64
# user                             object
# replyCount                      float64
# retweetCount                    float64
# likeCount                       float64
# quoteCount                        int64
# conversationId                    int64
# lang                             object
# source                           object
# sourceUrl                        object
# sourceLabel                      object
# outlinks                         object
# tcooutlinks                      object
# media                            object
# retweetedTweet                  float64
# quotedTweet                      object
# inReplyToTweetId                float64
# inReplyToUser                    object
# ...
